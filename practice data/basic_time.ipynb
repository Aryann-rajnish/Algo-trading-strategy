# %%
import pandas as pd
import numpy as np
array = np.random.randn(10)
series = pd.Series(array)
series
# Out:
# 0    0.077357
# 1   -0.918804
# 2   -0.117093
# 3   -0.382449
# 4   -0.263229
# 5   -0.918064
# 6    0.836271
# 7   -0.789774
# 8   -0.088279
# 9    0.324300
# dtype: float64

# %%
result = series.agg(lambda num : num+2)

# %%
result
# Out:
# 0    2.077357
# 1    1.081196
# 2    1.882907
# 3    1.617551
# 4    1.736771
# 5    1.081936
# 6    2.836271
# 7    1.210226
# 8    1.911721
# 9    2.324300
# dtype: float64

# %%
func_list = [min, max, sorted]
result1, result2, result3 = series.agg(func_list)

# %%
result1
# Out:
# -0.918803521491203

# %%
data1 = pd.read_csv("BANKNIFTY-I.csv",index_col=2)
data2 = pd.read_csv("BANKNIFTY-I.csv",index_col=0,parse_dates=[['Date','Time']])

# %%
data2.head(10)
# Out:
#                           Ticker       Open       High        Low      Close  \
# Date_Time
# 2012-05-30 09:15:00  BANKNIFTY-I  9599.9004  9599.9004  9561.7998  9566.0000
# 2012-05-30 09:16:00  BANKNIFTY-I  9565.0996  9565.0996  9555.1504  9564.4004
# 2012-05-30 09:17:00  BANKNIFTY-I  9564.3496  9570.0000  9563.6504  9567.0000
# 2012-05-30 09:18:00  BANKNIFTY-I  9568.0000  9569.0000  9561.6504  9563.2500
# 2012-05-30 09:19:00  BANKNIFTY-I  9566.5498  9568.0000  9556.0000  9558.3496
# 2012-05-30 09:20:00  BANKNIFTY-I  9555.0000  9558.3496  9536.0000  9540.0000
# 2012-05-30 09:21:00  BANKNIFTY-I  9537.0000  9544.9502  9535.0498  9544.9502
# 2012-05-30 09:22:00  BANKNIFTY-I  9542.5000  9547.0996  9535.0000  9540.0996
# 2012-05-30 09:23:00  BANKNIFTY-I  9540.0996  9541.9004  9531.0000  9537.5000
# 2012-05-30 09:24:00  BANKNIFTY-I  9537.5000  9542.0000  9537.5000  9541.0000
#
#                      Volume
# Date_Time
# 2012-05-30 09:15:00    21375
# 2012-05-30 09:16:00    15475
# ...

# %%
data1.head()
# Out:
#                Ticker        Date       Open       High        Low      Close  \
# Time
# 09:15:00  BANKNIFTY-I  2012-05-30  9599.9004  9599.9004  9561.7998  9566.0000
# 09:16:00  BANKNIFTY-I  2012-05-30  9565.0996  9565.0996  9555.1504  9564.4004
# 09:17:00  BANKNIFTY-I  2012-05-30  9564.3496  9570.0000  9563.6504  9567.0000
# 09:18:00  BANKNIFTY-I  2012-05-30  9568.0000  9569.0000  9561.6504  9563.2500
# 09:19:00  BANKNIFTY-I  2012-05-30  9566.5498  9568.0000  9556.0000  9558.3496
#
#           Volume
# Time
# 09:15:00    21375
# 09:16:00    15475
# 09:17:00    13850
# 09:18:00    11250
# 09:19:00    16050

# %%
from datetime import datetime
datetime(year=2019,month=3,day=4)
# Out:
# datetime.datetime(2019, 3, 4, 0, 0)

# %%
from dateutil import parser
date = parser.parse('4th july ,2015')

# %%
date
# Out:
# datetime.datetime(2015, 7, 4, 0, 0)

# %%
date.strftime('%A')
# Out:
# 'Saturday'

# %%
import pandas as pd
date = pd.to_datetime("4th july 2015")
date
# Out:
# Timestamp('2015-07-04 00:00:00')

# %%
index = pd.DatetimeIndex(['2017-4-5','2017-4-6','2017-4-7'])

# %%
data = pd.Series([0,12,35],index=index)

# %%
data
# Out:
# 2017-04-05     0
# 2017-04-06    12
# 2017-04-07    35
# dtype: int64

# %%
dates = pd.to_datetime([datetime(2015,4,7),'2017-4-8',"9 april,2017",'20170410'])

# %%
dates
# Out:
# DatetimeIndex(['2015-04-07', '2017-04-08', '2017-04-09', '2017-04-10'], dtype='datetime64[ns]', freq=None)

# %%
dates.to_period('D')
# Out:
# PeriodIndex(['2015-04-07', '2017-04-08', '2017-04-09', '2017-04-10'], dtype='period[D]', freq='D')

# %%
dates - dates[0]
# Out:
# TimedeltaIndex(['0 days', '732 days', '733 days', '734 days'], dtype='timedelta64[ns]', freq=None)

# %%
datess = pd.date_range('2015-7-7','2017-7-7')

# %%
datess
# Out:
# DatetimeIndex(['2015-07-07', '2015-07-08', '2015-07-09', '2015-07-10',
#                '2015-07-11', '2015-07-12', '2015-07-13', '2015-07-14',
#                '2015-07-15', '2015-07-16',
#                ...
#                '2017-06-28', '2017-06-29', '2017-06-30', '2017-07-01',
#                '2017-07-02', '2017-07-03', '2017-07-04', '2017-07-05',
#                '2017-07-06', '2017-07-07'],
#               dtype='datetime64[ns]', length=732, freq='D')

# %%
pd.date_range('2015-5-5',periods=5,freq="H")
# Out:
# DatetimeIndex(['2015-05-05 00:00:00', '2015-05-05 01:00:00',
#                '2015-05-05 02:00:00', '2015-05-05 03:00:00',
#                '2015-05-05 04:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
data1.head()
# Out:
#                Ticker        Date       Open       High        Low      Close  \
# Time
# 09:15:00  BANKNIFTY-I  2012-05-30  9599.9004  9599.9004  9561.7998  9566.0000
# 09:16:00  BANKNIFTY-I  2012-05-30  9565.0996  9565.0996  9555.1504  9564.4004
# 09:17:00  BANKNIFTY-I  2012-05-30  9564.3496  9570.0000  9563.6504  9567.0000
# 09:18:00  BANKNIFTY-I  2012-05-30  9568.0000  9569.0000  9561.6504  9563.2500
# 09:19:00  BANKNIFTY-I  2012-05-30  9566.5498  9568.0000  9556.0000  9558.3496
#
#           Volume
# Time
# 09:15:00    21375
# 09:16:00    15475
# 09:17:00    13850
# 09:18:00    11250
# 09:19:00    16050

# %%
type(data1)
# Out:
# pandas.core.frame.DataFrame

# %%
base = datetime.today()

# %%
base
from datetime import timedelta

# %%
date_list = [base - timedelta(days=x) for x in range(0,365)]
date_list
# Out:
# [datetime.datetime(2019, 5, 9, 9, 15, 54, 56242),
#  datetime.datetime(2019, 5, 8, 9, 15, 54, 56242),
#  datetime.datetime(2019, 5, 7, 9, 15, 54, 56242),
#  datetime.datetime(2019, 5, 6, 9, 15, 54, 56242),
#  datetime.datetime(2019, 5, 5, 9, 15, 54, 56242),
#  datetime.datetime(2019, 5, 4, 9, 15, 54, 56242),
#  datetime.datetime(2019, 5, 3, 9, 15, 54, 56242),
#  datetime.datetime(2019, 5, 2, 9, 15, 54, 56242),
#  datetime.datetime(2019, 5, 1, 9, 15, 54, 56242),
#  datetime.datetime(2019, 4, 30, 9, 15, 54, 56242),
#  datetime.datetime(2019, 4, 29, 9, 15, 54, 56242),
#  datetime.datetime(2019, 4, 28, 9, 15, 54, 56242),
#  datetime.datetime(2019, 4, 27, 9, 15, 54, 56242),
#  datetime.datetime(2019, 4, 26, 9, 15, 54, 56242),
#  datetime.datetime(2019, 4, 25, 9, 15, 54, 56242),
#  datetime.datetime(2019, 4, 24, 9, 15, 54, 56242),
#  datetime.datetime(2019, 4, 23, 9, 15, 54, 56242),
#  datetime.datetime(2019, 4, 22, 9, 15, 54, 56242),
#  datetime.datetime(2019, 4, 21, 9, 15, 54, 56242),
# ...

# %%
score_list = list(np.random.randint(low=1,high=1000,size=365))

# %%
data = pd.DataFrame()

# %%
data['Date']= date_list
data['Date'] = pd.to_datetime(data['Date'])
data.index = data.Date

# %%
data['score_list']=score_list

# %%
data.drop(columns=['Date'])
# Out:
#                             score_list
# Date
# 2019-05-09 09:15:54.056242         421
# 2019-05-08 09:15:54.056242         556
# 2019-05-07 09:15:54.056242         629
# 2019-05-06 09:15:54.056242         904
# 2019-05-05 09:15:54.056242          98
# 2019-05-04 09:15:54.056242         539
# 2019-05-03 09:15:54.056242         452
# 2019-05-02 09:15:54.056242         719
# 2019-05-01 09:15:54.056242         435
# 2019-04-30 09:15:54.056242         991
# 2019-04-29 09:15:54.056242         834
# 2019-04-28 09:15:54.056242         304
# 2019-04-27 09:15:54.056242         129
# 2019-04-26 09:15:54.056242         110
# 2019-04-25 09:15:54.056242          11
# 2019-04-24 09:15:54.056242         581
# 2019-04-23 09:15:54.056242         500
# 2019-04-22 09:15:54.056242         170
# 2019-04-21 09:15:54.056242         141
# 2019-04-20 09:15:54.056242         508
# 2019-04-19 09:15:54.056242          32
# 2019-04-18 09:15:54.056242         443
# 2019-04-17 09:15:54.056242         216
# ...

# %%
data1.head(20)
# Out:
#                Ticker        Date       Open       High        Low      Close  \
# Time
# 09:15:00  BANKNIFTY-I  2012-05-30  9599.9004  9599.9004  9561.7998  9566.0000
# 09:16:00  BANKNIFTY-I  2012-05-30  9565.0996  9565.0996  9555.1504  9564.4004
# 09:17:00  BANKNIFTY-I  2012-05-30  9564.3496  9570.0000  9563.6504  9567.0000
# 09:18:00  BANKNIFTY-I  2012-05-30  9568.0000  9569.0000  9561.6504  9563.2500
# 09:19:00  BANKNIFTY-I  2012-05-30  9566.5498  9568.0000  9556.0000  9558.3496
# 09:20:00  BANKNIFTY-I  2012-05-30  9555.0000  9558.3496  9536.0000  9540.0000
# 09:21:00  BANKNIFTY-I  2012-05-30  9537.0000  9544.9502  9535.0498  9544.9502
# 09:22:00  BANKNIFTY-I  2012-05-30  9542.5000  9547.0996  9535.0000  9540.0996
# 09:23:00  BANKNIFTY-I  2012-05-30  9540.0996  9541.9004  9531.0000  9537.5000
# 09:24:00  BANKNIFTY-I  2012-05-30  9537.5000  9542.0000  9537.5000  9541.0000
# 09:25:00  BANKNIFTY-I  2012-05-30  9542.0000  9545.0000  9532.3496  9543.5000
# ...

# %%
data1.groupby(data1['Date'])
data1.first
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-a04d737e77b0> in <module>()
#       1 data1.groupby(data1['Date'])
# ----> 2 data1.first()
#
# TypeError: first() missing 1 required positional argument: 'offset'

# %%
df.groupby().agg({'Low': lambda s: s.min(),'High': lambda s: s.max(),'Open': lambda s: s[0],'Close': lambda s: s[-1],
'Volume': lambda s: s.sum()})

# %%
import pandas as pd
data3 = pd.read_csv("BANKNIFTY-I.csv",index_col=2)

# %%
data3.head()
# Out:
#                Ticker        Date       Open       High        Low      Close  \
# Time
# 09:15:00  BANKNIFTY-I  2012-05-30  9599.9004  9599.9004  9561.7998  9566.0000
# 09:16:00  BANKNIFTY-I  2012-05-30  9565.0996  9565.0996  9555.1504  9564.4004
# 09:17:00  BANKNIFTY-I  2012-05-30  9564.3496  9570.0000  9563.6504  9567.0000
# 09:18:00  BANKNIFTY-I  2012-05-30  9568.0000  9569.0000  9561.6504  9563.2500
# 09:19:00  BANKNIFTY-I  2012-05-30  9566.5498  9568.0000  9556.0000  9558.3496
#
#           Volume
# Time
# 09:15:00    21375
# 09:16:00    15475
# 09:17:00    13850
# 09:18:00    11250
# 09:19:00    16050

# %%
data4 = pd.read_csv("BANKNIFTY-I.csv",index_col=0,parse_dates=[["Date",'Time']])

# %%
data4.head()
# Out:
#                           Ticker       Open       High        Low      Close  \
# Date_Time
# 2012-05-30 09:15:00  BANKNIFTY-I  9599.9004  9599.9004  9561.7998  9566.0000
# 2012-05-30 09:16:00  BANKNIFTY-I  9565.0996  9565.0996  9555.1504  9564.4004
# 2012-05-30 09:17:00  BANKNIFTY-I  9564.3496  9570.0000  9563.6504  9567.0000
# 2012-05-30 09:18:00  BANKNIFTY-I  9568.0000  9569.0000  9561.6504  9563.2500
# 2012-05-30 09:19:00  BANKNIFTY-I  9566.5498  9568.0000  9556.0000  9558.3496
#
#                      Volume
# Date_Time
# 2012-05-30 09:15:00    21375
# 2012-05-30 09:16:00    15475
# 2012-05-30 09:17:00    13850
# 2012-05-30 09:18:00    11250
# 2012-05-30 09:19:00    16050

# %%
type(data4['2012-05-30 09':'2012-05-30 10'].Close)
# Out:
# pandas.core.series.Series

# %%
data4['2012-05-30 09':'2012-05-30 10'].Close.mean()
# Out:
# 9530.959523809524

# %%
data4.head()
# Out:
#                           Ticker       Open       High        Low      Close  \
# Date_Time
# 2012-05-30 09:15:00  BANKNIFTY-I  9599.9004  9599.9004  9561.7998  9566.0000
# 2012-05-30 09:16:00  BANKNIFTY-I  9565.0996  9565.0996  9555.1504  9564.4004
# 2012-05-30 09:17:00  BANKNIFTY-I  9564.3496  9570.0000  9563.6504  9567.0000
# 2012-05-30 09:18:00  BANKNIFTY-I  9568.0000  9569.0000  9561.6504  9563.2500
# 2012-05-30 09:19:00  BANKNIFTY-I  9566.5498  9568.0000  9556.0000  9558.3496
#
#                      Volume
# Date_Time
# 2012-05-30 09:15:00    21375
# 2012-05-30 09:16:00    15475
# 2012-05-30 09:17:00    13850
# 2012-05-30 09:18:00    11250
# 2012-05-30 09:19:00    16050

# %%
data4.Period("2012")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-a7760d93c22a> in <module>()
# ----> 1 data4.Period("2012")
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Period'

# %%
len(data4)
# Out:
# 412117

# %%
import numpy as np
import pandas as pd
rng = np.random.randn(1,1000,1000)

# %%
rng.shape
# Out:
# (1, 1000, 1000)
